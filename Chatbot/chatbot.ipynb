# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    import nltk
except:
    # !pip install nltk
    import nltk

# %%
import nltk
nltk.download('punkt')
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/prabuddhachowdhury/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install tensorflow
import tensorflow as tf
import random
import json
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (1.9 kB)
# Collecting tensorflow-macos==2.13.0
#   Downloading tensorflow_macos-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (189.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.3/189.3 MB 2.4 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-estimator<2.14,>=2.13.0
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 3.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (22.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 13.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.12.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.1.21
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting keras<2.14,>=2.13.1
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.2 MB/s eta 0:00:00a 0:00:01m
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.4.0)
# Requirement already satisfied: setuptools in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (65.6.3)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.14.1)
# Collecting tensorboard<2.14,>=2.13
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 8.1 MB/s eta 0:00:0000:01:00:01
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: h5py>=2.9.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.7.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.56.2-cp310-cp310-macosx_12_0_universal2.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 11.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.38.4)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 877.4 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: markdown>=2.6.8 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.28.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (5.3.1)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<2.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.14)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-estimator, tensorboard-data-server, rsa, opt-einsum, oauthlib, keras, grpcio, google-pasta, gast, astunparse, absl-py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.22.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.56.2 keras-2.13.1 libclang-16.0.6 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-macos-2.13.0 termcolor-2.3.0

# %%
with open('intents.json') as json_data:
    data = json.load(json_data)

# %%
data
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'How are you', 'Is anyone there?', 'Hello', 'Good day'],
#    'responses': ['Hello, thanks for visiting',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context_set': ''},
#   {'tag': 'goodbye',
#    'patterns': ['Bye', 'See you later', 'Goodbye'],
#    'responses': ['See you later, thanks for visiting',
#     'Have a nice day',
#     'Bye! Come back again soon.']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks', 'Thank you', "That's helpful"],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure']},
#   {'tag': 'chatbot',
#    'patterns': ['Who built this chatbot?',
#     'Tell me about Chatbot',
#     'What is this chatbot name?'],
#    'responses': ['Hi, I am Chatbot designed by Mayank.',
#     'Thanks for asking. I am designed by Mayank Bajaj.',
#     'I am a chatbot.']},
#   {'tag': 'location',
#    'patterns': ['What is your location?',
#     'Where are you located?',
#     'What is your address?'],
#    'responses': ["We are from World's largest Democracy India.",
#     'You can visit India to meet us',
#     'Thans for your Interest. I live in India.']},
#   {'tag': 'connect',
#    'patterns': ['Give me your social media accounts link',
#     'Where can we connect',
#     'How can i reach out to you?',
#     'Is there any way we can connect'],
#    'responses': ['You can connect me on Linkedin or Github \n Linkedin - https://www.linkedin.com/in/mayank-bajaj/ \n Github - https://github.com/mayank8200',
#     'You can visit https://mayank-bajaj.me']},
#   {'tag': 'movies',
#    'patterns': ['Which is your favourite movie?',
#     'Suggest me some movies',
#     'Recommend movies'],
#    'responses': ['3 idiots',
#     'Hera Pheri',
#     'Lage Raho Munna Bhai',
#     'OMG: Oh My God!',
#     'PK',
#     'Yeh Jawani hai Deewani',
#     'Zindagi na Milegi Doobara',
#     'Ludo']},
#   {'tag': 'about',
#    'patterns': ['Who are you?', 'Tell me about Yourself', 'What is this?'],
#    'responses': ['Hi, I am Mayank. Nice to meet you. I made this chatbot for fun and practice.',
#     'Thanks for asking. I am Mayank Bajaj, coder by profession but ML enthusiast by passion.']}]}

# %%
words=[]
classes=[]
documents=[]
ignore_words=['?','!']

# loop through each sentence in our intents patterns
for intent in data['intents']:
    for pattern in intent['patterns']:
        # tokenize each word in the sentence
        w=nltk.word_tokenize(pattern)
        # add to our words list
        words.extend(w)
        # add to documents in our corpus
        documents.append((w,intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# Perform stemming and lemmatization on the data
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
words= [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
lemmatizer = WordNetLemmatizer()
words= [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]

# remove duplicates and sort
words= sorted(list(set(words)))

# sort classes
classes= sorted(list(set(classes)))

# documents= combination between patterns and intents
print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/prabuddhachowdhury/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/prabuddhachowdhury/nltk_data...
# 27 documents
# 8 classes ['about', 'chatbot', 'connect', 'goodbye', 'greeting', 'location', 'movies', 'thanks']
# 52 unique lemmatized words ["'s", 'about', 'account', 'address', 'ani', 'anyon', 'are', 'built', 'bye', 'can', 'chatbot', 'connect', 'day', 'favourit', 'give', 'good', 'goodbi', 'hello', 'help', 'hi', 'how', 'i', 'is', 'later', 'link', 'locat', 'me', 'medium', 'movi', 'name', 'out', 'reach', 'recommend', 'see', 'social', 'some', 'suggest', 'tell', 'thank', 'that', 'there', 'thi', 'to', 'way', 'we', 'what', 'where', 'which', 'who', 'you', 'your', 'yourself']

# %%
import numpy as np

# Create training data (input and output pairs)
training = []
output = []

# Create an empty array for output
output_empty = [0] * len(classes)

# Create training set, bag of words for each sentence
for doc in documents:
    # Initialize bag of words
    bag = [0] * len(words)
    # List of tokenized words for the pattern
    pattern_words = doc[0]
    # Stem each word
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # Create bag of words array with 1, if word match found in current pattern
    for w in pattern_words:
        if w in words:
            bag[words.index(w)] = 1
    # Output is 1 for current tag and 0 for rest of other tags
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    # Append bag of words and output row to training list
    training.append([np.array(bag, dtype=np.float32), np.array(output_row, dtype=np.float32)])

# Shuffle features and turn into np.array
random.shuffle(training)
training = np.array(training, dtype=object)

# Create training and testing lists. X - patterns, Y - intents
train_x = list(training[:, 0])
train_y = list(training[:, 1])

# %%
model= tf.keras.Sequential()
model.add(tf.keras.layers.Dense(10, input_shape=(len(train_x[0]),)))
model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Dense(len(train_y[0]), activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(np.array(train_x), np.array(train_y), epochs=100, batch_size=50, verbose=1)
model.save('chatbot_model.h5')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 132ms/step - loss: 2.2160 - accuracy: 0.1481
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2045 - accuracy: 0.1852
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1933 - accuracy: 0.1852
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1821 - accuracy: 0.2222
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1711 - accuracy: 0.2222
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1601 - accuracy: 0.2222
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1493 - accuracy: 0.2222
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1386 - accuracy: 0.2222
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1280 - accuracy: 0.2222
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1175 - accuracy: 0.2593
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1072 - accuracy: 0.2593
# Epoch 12/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0969 - accuracy: 0.2593
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0867 - accuracy: 0.2963
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0766 - accuracy: 0.3333
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0665 - accuracy: 0.3333
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0566 - accuracy: 0.3333
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0467 - accuracy: 0.3333
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0369 - accuracy: 0.3333
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0272 - accuracy: 0.3333
# Epoch 20/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0175 - accuracy: 0.3333
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0079 - accuracy: 0.3333
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9984 - accuracy: 0.3333
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9888 - accuracy: 0.3333
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9794 - accuracy: 0.3704
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9699 - accuracy: 0.3704
# Epoch 26/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9605 - accuracy: 0.3704
# Epoch 27/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9512 - accuracy: 0.3704
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9418 - accuracy: 0.3704
# Epoch 29/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9325 - accuracy: 0.4074
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9232 - accuracy: 0.4074
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9139 - accuracy: 0.4074
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9046 - accuracy: 0.4074
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8954 - accuracy: 0.4074
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8861 - accuracy: 0.4074
# Epoch 35/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8769 - accuracy: 0.4444
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8676 - accuracy: 0.4444
# Epoch 37/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8584 - accuracy: 0.4444
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8491 - accuracy: 0.4444
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8398 - accuracy: 0.4444
# Epoch 40/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8306 - accuracy: 0.4444
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8213 - accuracy: 0.4444
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8120 - accuracy: 0.4444
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8027 - accuracy: 0.4444
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7934 - accuracy: 0.4444
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7841 - accuracy: 0.4444
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7748 - accuracy: 0.4444
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7654 - accuracy: 0.4444
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7560 - accuracy: 0.4444
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7466 - accuracy: 0.4444
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7372 - accuracy: 0.4815
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7277 - accuracy: 0.4815
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7183 - accuracy: 0.4815
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7088 - accuracy: 0.4815
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6992 - accuracy: 0.5185
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6897 - accuracy: 0.5185
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6801 - accuracy: 0.5185
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6705 - accuracy: 0.5556
# Epoch 58/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6609 - accuracy: 0.5556
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6512 - accuracy: 0.5556
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6416 - accuracy: 0.5556
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6318 - accuracy: 0.5556
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6221 - accuracy: 0.5556
# Epoch 63/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6124 - accuracy: 0.5556
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6026 - accuracy: 0.5556
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5928 - accuracy: 0.5556
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5829 - accuracy: 0.5556
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5730 - accuracy: 0.5556
# Epoch 68/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5632 - accuracy: 0.5556
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5532 - accuracy: 0.5926
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5433 - accuracy: 0.6296
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5334 - accuracy: 0.6667
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5234 - accuracy: 0.6667
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5134 - accuracy: 0.6667
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5033 - accuracy: 0.6667
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4933 - accuracy: 0.6667
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4832 - accuracy: 0.6667
# Epoch 77/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4732 - accuracy: 0.6667
# Epoch 78/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4631 - accuracy: 0.6667
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4530 - accuracy: 0.6667
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4429 - accuracy: 0.6667
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4327 - accuracy: 0.6667
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4226 - accuracy: 0.6667
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4124 - accuracy: 0.6667
# Epoch 84/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4023 - accuracy: 0.6667
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3921 - accuracy: 0.6667
# Epoch 86/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3820 - accuracy: 0.6667
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3718 - accuracy: 0.7037
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3616 - accuracy: 0.7037
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3514 - accuracy: 0.7037
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3413 - accuracy: 0.7037
# Epoch 91/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3311 - accuracy: 0.7037
# Epoch 92/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3209 - accuracy: 0.7037
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3108 - accuracy: 0.7037
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3006 - accuracy: 0.7037
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2905 - accuracy: 0.7037
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2804 - accuracy: 0.7037
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2703 - accuracy: 0.7037
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2602 - accuracy: 0.7037
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2501 - accuracy: 0.7037
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2400 - accuracy: 0.7037
# /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pickle
pickle.dump({'words':words, 'classes':classes},open('chatbot_model.h5','wb'))

# %%
from keras.models import load_model
import os

model_path = 'chatbot_model.h5'
if os.path.exists(model_path):
    try:
        model = load_model(model_path)  # Load the trained model
    except OSError as e:
        print("Unable to load model:", e)
else:
    print("Model file not found at path:", model_path)
# Out:
# Unable to load model: Unable to open file (file signature not found)

# %%
# Restoring all data structures
import pickle
data = pickle.load(open("chatbot_model.h5", "rb"))
words = data['words']
classes = data['classes']

# %%
with open('intents.json') as file:
    data = json.load(file)

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# %%
# Returning the bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # Tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # Bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))

# %%
ERROR_THRESHOLD = 0.30
def classify(sentence):
    # generate probabilities from the model
    results = model.predict([bag_of_words(sentence, words)])[0]
    # filter out predictions below a threshold
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def response(sentence):
    results.classify(sentence)
    # If we have a classification then find the matching intent tag
    if results:
        # loop as long as there re matches to process
        while results:
            # for each intent key, find the matching tag
            for i in intents['intents']:
                # find a tag matching the first result
                if i['tag'] == results[0][0]:
                    # a random response from the intent
                    return print(random.choice(i['responses']))

            results.pop(0)
